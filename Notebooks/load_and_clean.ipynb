# %%
import os, sys
sys.path.append(os.path.abspath(".."))

# %%
from src.config import DATA_PATH
import os

print("DATA_PATH:", DATA_PATH)
print("File exists:", os.path.exists(DATA_PATH))
# Out:
# DATA_PATH: c:\Users\razan\Downloads\tel\data\WA_Fn-UseC_-Telco-Customer-Churn.csv
# File exists: True

# %%
import os
import pandas as pd

# %%
from src.config import DATA_PATH
from src.io_utils import load_telco_data
from src.clean import clean_telco

# %%
os.makedirs("outputs", exist_ok=True)

# %%
from src.io_utils import load_telco_data
from src.config import DATA_PATH

df_raw = load_telco_data(DATA_PATH)
print("Raw shape:", df_raw.shape)
df_raw.head()
# Out:
# Raw shape: (7043, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df = clean_telco(df_raw)
print("Clean shape:", df.shape)
display(df.head())
# Out:
# Clean shape: (7032, 21)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.to_csv("outputs/telco_clean.csv", index=False)
print("Saved: outputs/telco_clean.csv")
# Out:
# Saved: outputs/telco_clean.csv
